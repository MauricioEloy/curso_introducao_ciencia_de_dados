# %% [markdown]
# <p> <img src="../../imagens/LOGO_2.png"  align="midle"></p>
#
# **Data Science**<br>
#
# *profmauricioeloy@gmail.com | mauricioeloy@usp.br<br>*

# %% [markdown]
# **Sumário:**
#
# * [1. Conteúdo](#1)
# * [2. Módulos e Pacotes](#2)
#     * [2.1 Comando Import](#2.1)
#     * [2.2 Atributos e Métodos](#2.2)
#     * [2.2 Comando from](#2.2)
#     * [2.2 Instalação de um novo pacote](#2.2)

# %% [markdown]
# <a id="1"></a>
# <h1 style="background-color:#084d6e;font-family:newtimeroman;font-size:300%;color:white;text-align:center;border-radius: 15px 50px">Conteúdo</h1>
#
# * Módulos;
# * Pacotes.

# %% [markdown]
# <a id="2"></a>
# <h1 style="background-color:#084d6e;font-family:newtimeroman;font-size:300%;color:white;text-align:center;border-radius: 15px 50px">Módulos e Pacotes</h1>
#
# Módulos são simplesmente arquivos Python (extensão .py), que implementam um conjunto de funções e podem ser importados.
#
# Sintaxe:
# ```python
# import nome_modulo
# ```
#
# Um pacote é um módulo com um conjunto de módulos.
#
# Sintaxe:
#
# ```python
# import nome_pacote.nome_modulo
# ```

# %% [markdown]
# <a id="2.1"></a>
# <h2 style="background-color:#084d6e;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius: 15px 50px">Comando Import</h2>

# %%
def media(ls_numbers):
    media = sum(ls_numbers)/len(ls_numbers)
    return media

# %%
vel_iot = [60.0, 55.7, 43.0, 79.3, 41.4, 14.7]
media(vel_iot)
# Out:
# 49.01666666666666

# %%
import numpy

numpy.mean(vel_iot)
# Out:
# 49.01666666666666

# %%
mean(vel_iot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8025bb10dfcc> in <module>
# ----> 1 mean(vel_iot)
#
# NameError: name 'mean' is not defined

# %%
import numpy as np

np.mean(vel_iot)
# Out:
# 49.01666666666666

# %% [markdown]
# <a id="2.2"></a>
# <h2 style="background-color:#084d6e;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius: 15px 50px">Atributos e Métodos</h2>
#
# Um módulo pode ter atributos e métodos definidos, a sintaxe para acessá-los é a mesma ```nome_modulo.nome_metodo``` ou ```nome_modulo.nome_atributo```.
#
# Para verificar os atributos e métodos existentes em um módulo pode-se:
#
# 1. utilizar do método ```dir```;
# 2. acessar a documentação do módulo/pacote.

# %%
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'Bytes0',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'Datetime64',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Str0',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'Uint64',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
# ...

# %% [markdown]
# Duas formas de obter a documentação:
# 1. https://pypi.org/;
# 2. pesquisa.

# %% [markdown]
# <a id="2.3"></a>
# <h2 style="background-color:#084d6e;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius: 15px 50px">Comando from</h2>
#
# Através do comando ```from``` pode-se importar apenas elementos específicos de um módulo/pacote.
#
# Sintaxe:
#
# ```python
# from nome_modulo import nome_especifico
# ```

# %%
from numpy import mean

# %%
mean(vel_iot)
# Out:
# 49.01666666666666

# %% [markdown]
# <a id="2.4"></a>
# <h2 style="background-color:#084d6e;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius: 15px 50px">Instalação de um novo pacote</h2>
#
# Uma das formas de verificar os pacotes instalados é utilizando o comando ```conda list```.
#
# Este comando pode ser utilizado no prompt de comando ou em uma célula de código no jupyter-notebook precedido do símbolo ```!```.

# %%
# !conda list
# Out:
# # packages in environment at /home/mauricioeloy/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py38_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _libgcc_mutex             0.1                        main
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  custom                   py38_1
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        2.0.3                    py38_0
# anaconda-project          0.10.0             pyhd3eb1b0_0
# anyio                     2.2.0            py38h06a4308_1
# appdirs                   1.4.4                      py_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h27cfd23_1
# arviz                     0.11.2                   pypi_0    pypi
# asn1crypto                1.4.0                      py_0
# ...

# %% [markdown]
# Sintaxe para instalação:
#
# * ```conda install nome_pacote```
# * ```pip install nome_pacote```

# %%
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-fc7d1d298f0c> in <module>
# ----> 1 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# !pip install geopandas
# Out:
# ...
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
# ...

# %%
import geopandas
